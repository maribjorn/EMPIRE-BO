# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data from objective_values.dat
data = [
    3.820646e+09, 3.847480e+09, 3.874116e+09, 3.798371e+09, 3.876100e+09,
    3.789272e+09, 3.839532e+09, 3.885997e+09, 3.833644e+09, 3.859379e+09,
    3.870286e+09, 3.845571e+09, 3.782914e+09, 3.849735e+09, 3.861294e+09,
    3.794791e+09, 3.841153e+09, 3.796989e+09, 3.862695e+09, 3.793563e+09
]

# Create histogram
plt.figure(figsize=(10, 6))
plt.hist(data, bins=10, edgecolor='black')
plt.title('Objective Values for 20 Different Runs of BASE NZE', fontsize = '16')
plt.xlabel('Objective Values', fontsize = '14')
plt.ylabel('Frequency', fontsize = '14')
plt.xticks(fontsize = '14')

# Display the plot
plt.show()
